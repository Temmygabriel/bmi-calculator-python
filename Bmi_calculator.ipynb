# %% [markdown]
# # BMI Calculator (Python)
#
# This is a beginner-friendly Python project that calculates Body Mass Index (BMI)
# using:
# - Weight in kilograms
# - Height in feet and inches
#
# The program converts height to meters, calculates BMI, and classifies the result
# into standard BMI categories using conditional statements.
#
# ## Concepts Used
# - User input
# - Type casting (int, float)
# - Arithmetic operations
# - If / elif / else statements
# - Unit conversion
#
# ## Author
# Temitope Olatunji

# %%
weight_kg = float(input("Enter your weight in kilograms: "))

feet = int(input("Enter your height (feet): "))
inches = int(input("Enter remaining height (inches): "))
# Out:
# Enter your weight in kilograms:  73
# Enter your height (feet):  5
# Enter remaining height (inches):  7

# %%
# Convert height to meters

# %%
total_inches = feet * 12 + inches
height_m = total_inches * 0.0254

# %%
# Calculate BMI

# %%
bmi = weight_kg / (height_m ** 2)

# %%
# Display BMI

# %%
print(f"Your BMI is: {bmi:.2f}")
# Out:
# Your BMI is: 25.21

# %%
# Determine BMI category

# %%
if bmi <= 18.5:
    category = "Underweight"
elif bmi <= 25:
    category = "Normal weight"
elif bmi <= 30:
    category = "Overweight"
else:
    category = "Obese"

# %%
# Display result

# %%
print("BMI Category:", category)
# Out:
# BMI Category: Overweight
